# %% [markdown]
# # Test notebook
#
# This notebook is here to test that the binder is runnable, and demonstrate basic functionality.

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 20:33:18)
# [Clang 11.1.0 ]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)', title='Simple graph')
ax.grid()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
